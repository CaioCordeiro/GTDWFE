# %% [markdown]
# # Evaluating feature selection algorithms to apply in antimicrobial-resistant genes classification in Gram-negative bacterias.
#
# Explore feature selection and evaluation algorithms to select the most important features of antimicrobial-resistant genes in Gram-negative bacterias.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import cross_validate
from feature_selection.relieff_algorithm import apply_relieff
from comparators.scores import get_mean_scores
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/Ac_Sa_Ca_Kl_Ec/bla_all.csv")

# %%
df.describe()
# Out:
#        X.G1.1.1.1.  X.G1.1.1.2.  X.G1.1.1.3.  X.G1.1.1.4.  X.G1.1.1.5.  \
# count   107.000000   107.000000   107.000000   107.000000   107.000000
# mean      9.546110     0.995702     5.307196     6.349583     3.843472
# std       3.163466     0.593482     1.464356     1.733894     1.480018
# min       1.293103     0.000000     0.947867     0.645161     0.598802
# 25%       7.404220     0.639671     4.430558     5.339520     2.921814
# 50%       9.027778     0.946372     5.161290     6.086957     3.723404
# 75%      12.152157     1.355934     6.059658     7.649781     4.663963
# max      20.000000     3.030303    10.344828    10.185185     9.090909
#
#        X.G1.1.1.6.  X.G1.1.1.7.  X.G1.1.1.8.  X.G1.1.1.9.  X.G1.1.1.10.  ...  \
# count   107.000000   107.000000   107.000000   107.000000    107.000000  ...
# mean      7.201760     2.093861     6.229314     6.307413      9.653214  ...
# std       1.655267     1.029004     2.342338     2.619822      2.456389  ...
# ...

# %% [markdown]
# ## Discretizing

# %%
def discretize(df):
    for i in df.columns:
        if i != "Feature":
            df[i] = pd.qcut(df[i], q=5,  labels=False, precision=0, duplicates='drop')
    return df

# %%
df = discretize(df)

# %%
df.describe()
# Out:
#        X.G1.1.1.1.  X.G1.1.1.2.  X.G1.1.1.3.  X.G1.1.1.4.  X.G1.1.1.5.  \
# count   107.000000   107.000000   107.000000   107.000000   107.000000
# mean      2.000000     2.000000     2.000000     2.000000     1.990654
# std       1.434086     1.434086     1.434086     1.434086     1.430763
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     1.000000     1.000000     1.000000
# 50%       2.000000     2.000000     2.000000     2.000000     2.000000
# 75%       3.000000     3.000000     3.000000     3.000000     3.000000
# max       4.000000     4.000000     4.000000     4.000000     4.000000
#
#        X.G1.1.1.6.  X.G1.1.1.7.  X.G1.1.1.8.  X.G1.1.1.9.  X.G1.1.1.10.  ...  \
# count   107.000000   107.000000   107.000000   107.000000    107.000000  ...
# mean      1.990654     1.990654     2.000000     2.000000      2.000000  ...
# std       1.424154     1.430763     1.434086     1.434086      1.434086  ...
# ...

# %%
df
# Out:
#           Feature  X.G1.1.1.1.  X.G1.1.1.2.  X.G1.1.1.3.  X.G1.1.1.4.  \
# 0        ABQ42698            2            0            0            0
# 1    WP_063857785            3            1            0            0
# 2        AKN19343            3            1            0            0
# 3        CQR83532            2            4            0            0
# 4    WP_032492458            4            0            0            0
# ..            ...          ...          ...          ...          ...
# 102      CDL61843            1            2            3            3
# 103      CDL63342            4            4            3            4
# 104      CDL64114            0            3            2            0
# 105      CDL64552            4            1            1            3
# 106      CDL65005            4            4            3            1
#
#      X.G1.1.1.5.  X.G1.1.1.6.  X.G1.1.1.7.  X.G1.1.1.8.  X.G1.1.1.9.  ...  \
# ...

# %% [markdown]
# ## Dividing train and test data

# %%
#df = pd.get_dummies(df, columns=["Feature"])
y = df["Output"]
X = df.drop(["Output","Feature"], axis=1) 
X_copy = X.copy(deep=True)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=4)
clf = svm.SVC()
#clf = clf.fit(X_train, y_train)

# %%
X_copy = apply_relieff(X_copy.to_numpy(), y)
print(len(X_copy))
X_train2, X_test2, y_train2, y_test2 = train_test_split( X_copy, y, test_size=0.30, random_state=4)
clf2 = svm.SVC()
#clf2 = clf2.fit(X_train2, y_train2)
# Out:
# 107

# %%
disp = plot_confusion_matrix(clf, X_test, y_test,
                                 cmap=plt.cm.Blues)
disp.ax_.set_title("Confusion Matrix")
disp = plot_confusion_matrix(clf2, X_test2, y_test2,
                                 cmap=plt.cm.Blues)

plt.show()

# %%
scores = cross_val_score(clf, X_test, y_test, cv=5, scoring='f1_macro')
print("%0.2f accuracy with a standard deviation of %0.2f on model 1" % (scores.mean(), scores.std()))
scores = cross_val_score(clf, X_test2, y_test2, cv=5, scoring='f1_macro')
print("%0.2f accuracy with a standard deviation of %0.2f on model 2" % (scores.mean(), scores.std()))
# Out:
# 0.90 accuracy with a standard deviation of 0.14 on model 1
# 0.82 accuracy with a standard deviation of 0.18 on model 2

# %%
y_pred = cross_val_predict(clf, X_test, y_test, cv=10)
y_pred2 = cross_val_predict(clf2, X_test2, y_test2, cv=10)

# %%
y_results = cross_validate(clf, X, y, cv=10, return_train_score=True)
get_mean_scores(y_results)
# Out:
# {'fit_time': 0.005000877380371094,
#  'score_time': 0.003400850296020508,
#  'test_score': 0.990909090909091,
#  'train_score': 1.0}

# %%
print(accuracy_score(y_test, y_pred))
print(accuracy_score(y_test2, y_pred2))
# Out:
# 0.8787878787878788
# 0.8181818181818182

# %%
print(clf.score(X_test,y_test))
print(clf2.score(X_test2,y_test2))
# Out:
# 0.9696969696969697
# 0.8484848484848485
